# %%
from random import shuffle


class Card:
    suits = ["spades", "hearts", "diamonds", "clubs"]
    values = [None, None,"2", "3", "4", "5", "6", "7", "8", "9", "10",
              "Jack", "Queen", "King", "Ace"]

    def __init__(self, v, s):
        """suit + value are ints"""
        self.value = v
        self.suit = s

    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
            return self,suit < c2.suit
        return False

    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
            if self.suit > c2.suit:
                return True
            else:
                return False
        return False

    def __repr__(self):
        v = self.values[self.value] +\
            " of " + \
            self.suits[self.suit]
        return v


class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

    def rm_card(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()


class Player:
    def __init__(self, name):
        self.wins = 0
        self.card = None
        self.name = name


class Game:
    def __init__(self):
        name1 = input("p1 name ")
        name2 = input("p2 name ")
        self.deck = Deck()
        self.p1 = Player(name1)
        self.p2 = Player(name2)

    def wins(self, winner):
        w = "{} wins this round"
        w = w.format(winner)
        print(w)

    def draw(self, p1n, p1c, p2n, p2c):
        d = "{} drew {} {} drew {}"
        d = d.format(p1n,
                     p1c,
                     p2n,
                     p2c)
        print(d)

    def play_game(self):
        cards = self.deck.cards
        print("beginning War!")
        while len(cards) >= 2:
            m = "q to quit. Any " + \
                "key to play:"
            response = input(m)
            if response == 'q':
                break
            p1c = self.deck.rm_card()
            p2c = self.deck.rm_card()
            p1n = self.p1.name
            p2n = self.p2.name
            self.draw(p1n,
                      p1c,
                      p2n,
                      p2c)
            if p1c > p2c:
                self.p1.wins += 1
                self.wins(self.p1.name)
            else:
                self.p2.wins += 1
                self.wins(self.p2.name)

        win = self.winner(self.p1,
                         self.p2)
        print("War is over.{} wins"
              .format(win))

    def winner(self, p1, p2):
        if p1.wins > p2.wins:
            return p1.name
        if p1.wins < p2.wins:
            return p2.name
        return "It was a tie!"

game = Game()
game.play_game()
# Out:
# p1 name 1
# p2 name 1
# beginning War!
# q to quit. Any key to play:1
# 1 drew 6 of diamonds 1 drew 8 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Ace of hearts 1 drew 2 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of clubs 1 drew 7 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of spades 1 drew Ace of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Queen of diamonds 1 drew 3 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of clubs 1 drew Jack of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of spades 1 drew Queen of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of diamonds 1 drew 5 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of hearts 1 drew Ace of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Queen of clubs 1 drew 10 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of diamonds 1 drew 7 of clubs
# 1 wins this round
# q to quit. Any key to play:11
# 1 drew King of spades 1 drew Ace of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of spades 1 drew King of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 10 of diamonds 1 drew 5 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of hearts 1 drew 2 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 10 of spades 1 drew 7 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of diamonds 1 drew 8 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 2 of hearts 1 drew Jack of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of spades 1 drew 10 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 9 of diamonds 1 drew 7 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of hearts 1 drew 2 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of clubs 1 drew 6 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of clubs 1 drew 6 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of clubs 1 drew 6 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 9 of clubs 1 drew 9 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Queen of hearts 1 drew 9 of hearts
# 1 wins this round
# War is over.1 wins

# %%
from random import shuffle


class Card:
    suits = ["spades",
             "hearts",
             "diamonds",
             "clubs"]

    values = [None, None,"2", "3",
              "4", "5", "6", "7",
              "8", "9", "10",
              "Jack", "Queen",
              "King", "Ace"]

    def __init__(self, v, s):
        """suit + value are ints"""
        self.value = v
        self.suit = s

    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
            if self.suit < c2.suit:
                return True
            else:
                return False
        return False

    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
            if self.suit > c2.suit:
                return True
            else:
                return False
        return False

    def __repr__(self):
        v = self.values[self.value] +\
            " of " + \
            self.suits[self.suit]
        return v


class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

    def rm_card(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()


class Player:
    def __init__(self, name):
        self.wins = 0
        self.card = None
        self.name = name


class Game:
    def __init__(self):
        name1 = input("p1 name ")
        name2 = input("p2 name ")
        self.deck = Deck()
        self.p1 = Player(name1)
        self.p2 = Player(name2)

    def wins(self, winner):
        w = "{} wins this round"
        w = w.format(winner)
        print(w)

    def draw(self, p1n, p1c, p2n, p2c):
        d = "{} drew {} {} drew {}"
        d = d.format(p1n,
                     p1c,
                     p2n,
                     p2c)
        print(d)

    def play_game(self):
        cards = self.deck.cards
        print("beginning War!")
        while len(cards) >= 2:
            m = "q to quit. Any " + \
                "key to play:"
            response = input(m)
            if response == 'q':
                break
            p1c = self.deck.rm_card()
            p2c = self.deck.rm_card()
            p1n = self.p1.name
            p2n = self.p2.name
            self.draw(p1n,
                      p1c,
                      p2n,
                      p2c)
            if p1c > p2c:
                self.p1.wins += 1
                self.wins(self.p1.name)
            else:
                self.p2.wins += 1
                self.wins(self.p2.name)

        win = self.winner(self.p1,
                         self.p2)
        print("War is over.{} wins"
              .format(win))

    def winner(self, p1, p2):
        if p1.wins > p2.wins:
            return p1.name
        if p1.wins < p2.wins:
            return p2.name
        return "It was a tie!"

game = Game()
game.play_game()
# Out:
# p1 name 1
# p2 name 1
# beginning War!
# q to quit. Any key to play:11
# 1 drew 7 of diamonds 1 drew 9 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of spades 1 drew 2 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of diamonds 1 drew 10 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 6 of spades 1 drew 2 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of hearts 1 drew 5 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of clubs 1 drew Ace of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 9 of diamonds 1 drew 3 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Queen of hearts 1 drew 7 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 2 of clubs 1 drew 7 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of clubs 1 drew 8 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of diamonds 1 drew 2 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 10 of hearts 1 drew 6 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Ace of hearts 1 drew Queen of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of spades 1 drew 6 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of hearts 1 drew King of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of spades 1 drew Queen of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of clubs 1 drew 8 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of diamonds 1 drew 7 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 6 of hearts 1 drew Queen of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of clubs 1 drew 3 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 9 of clubs 1 drew Jack of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 10 of diamonds 1 drew 5 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of spades 1 drew 4 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Ace of spades 1 drew 9 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Ace of clubs 1 drew 3 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of spades 1 drew 10 of clubs
# 1 wins this round
# War is over.1 wins

# %%
from random import shuffle


class Card:
    suits = ["spades", "hearts", "diamonds", "clubs"]

    values = [None, None,"2", "3", "4", "5", "6", "7", "8", "9", "10",
              "Jack", "Queen", "King", "Ace"]

    def __init__(self, v, s):
        """suit + value are ints"""
        self.value = v
        self.suit = s

    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
#            if self.suit < c2.suit:
#                return True
#            else:
#                return False
            return self.suit < c2.suit
        return False

    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
#            if self.suit > c2.suit:
#                return True
#            else:
#                return False
            return self.suit > c2.suit
        return False

    def __repr__(self):
        v = self.values[self.value] +\
            " of " + \
            self.suits[self.suit]
        return v


class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

#    def rm_card(self):
    def draw(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()

class Player:
    def __init__(self, name):
        self.wins = 0
        self.card = None
        self.name = name


class Game:
    def __init__(self):
        name1 = input("p1 name ")
        name2 = input("p2 name ")
        self.deck = Deck()
        self.p1 = Player(name1)
        self.p2 = Player(name2)

#    def wins(self, winner):
#        w = "{} wins this round"
#        w = w.format(winner)
#        print(w)

    def print_winner(self, winner)
        w = "{} wins this round"
        print(w.format(winner.name))

#    def draw(self, p1n, p1c, p2n, p2c):
#        d = "{} drew {} {} drew {}"
#        d = d.format(p1n, p1c, p2n, p2c)
#        print(d)

    def print_draw(self, p1,p2)
        d = "{} drew {} {} drew {}"
        print(d.format(p1.name, p1.card, p2.name, p2.card, ))

    def play_game(self):
        cards = self.deck.cards
        print("beginning War!")
        while len(cards) >= 2:
            m = "q to quit. Any " + \
                "key to play:"
            response = input(m)
            if response == 'q':
                break

#            p1c = self.deck.rm_card()
#            p2c = self.deck.rm_card()
#            p1n = self.p1.name
#            p2n = self.p2.name
#            self.draw(p1n, p1c, p2n, p2c)
#            if p1c > p2c:
#                self.p1.wins += 1
#                self.wins(self.p1.name)
#            else:
#                self.p2.wins += 1
#                self.wins(self.p2.name)

            self.p1.card = self.deck.draw()
            self.p2.card = self.deck.draw()
            self.print.card(self.p1, self.p2)
            if self.p1.card > self.p2.card:
                self.p1.wins += 1
                self.print_winner(self.p1)
            else:
                self.p2.wins += 1
                self.print_winner(self.p2)

        win = self.winner(self.p1,
                         self.p2)
        print("War is over.{} wins"
              .format(win))

    def winner(self, p1, p2):
        if p1.wins > p2.wins:
            return p1.name
        if p1.wins < p2.wins:
            return p2.name
        return "It was a tie!"

game = Game()
game.play_game()
# Out:
#   File "<ipython-input-3-f38a3fb3016f>", line 77
#     def print_winner(self, winner)
#                                   ^
# SyntaxError: invalid syntax

# %%
from random import shuffle


class Card:
    suits = ["spades", "hearts", "diamonds", "clubs"]

    values = [None, None,"2", "3", "4", "5", "6", "7", "8", "9", "10",
              "Jack", "Queen", "King", "Ace"]

    def __init__(self, v, s):
        """suit + value are ints"""
        self.value = v
        self.suit = s

    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
#            if self.suit < c2.suit:
#                return True
#            else:
#                return False
            return self.suit < c2.suit
        return False

    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
#            if self.suit > c2.suit:
#                return True
#            else:
#                return False
            return self.suit > c2.suit
        return False

    def __repr__(self):
        v = self.values[self.value] +\
            " of " + \
            self.suits[self.suit]
        return v


class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

#    def rm_card(self):
    def draw(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()

class Player:
    def __init__(self, name):
        self.wins = 0
        self.card = None
        self.name = name


class Game:
    def __init__(self):
        name1 = input("p1 name ")
        name2 = input("p2 name ")
        self.deck = Deck()
        self.p1 = Player(name1)
        self.p2 = Player(name2)

#    def wins(self, winner):
#        w = "{} wins this round"
#        w = w.format(winner)
#        print(w)

    def print_winner(self, winner):
        w = "{} wins this round"
        print(w.format(winner.name))

#    def draw(self, p1n, p1c, p2n, p2c):
#        d = "{} drew {} {} drew {}"
#        d = d.format(p1n, p1c, p2n, p2c)
#        print(d)

    def print_draw(self, p1,p2):
        d = "{} drew {} {} drew {}"
        print(d.format(p1.name, p1.card, p2.name, p2.card, ))

    def play_game(self):
        cards = self.deck.cards
        print("beginning War!")
        while len(cards) >= 2:
            m = "q to quit. Any " + \
                "key to play:"
            response = input(m)
            if response == 'q':
                break

#            p1c = self.deck.rm_card()
#            p2c = self.deck.rm_card()
#            p1n = self.p1.name
#            p2n = self.p2.name
#            self.draw(p1n, p1c, p2n, p2c)
#            if p1c > p2c:
#                self.p1.wins += 1
#                self.wins(self.p1.name)
#            else:
#                self.p2.wins += 1
#                self.wins(self.p2.name)

            self.p1.card = self.deck.draw()
            self.p2.card = self.deck.draw()
            self.print.card(self.p1, self.p2)
            if self.p1.card > self.p2.card:
                self.p1.wins += 1
                self.print_winner(self.p1)
            else:
                self.p2.wins += 1
                self.print_winner(self.p2)

        win = self.winner(self.p1,
                         self.p2)
        print("War is over.{} wins"
              .format(win))

    def winner(self, p1, p2):
        if p1.wins > p2.wins:
            return p1.name
        if p1.wins < p2.wins:
            return p2.name
        return "It was a tie!"

game = Game()
game.play_game()
# Out:
# p1 name 1
# p2 name 1
# beginning War!
# q to quit. Any key to play:1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-498414cfe11d> in <module>()
#     132
#     133 game = Game()
# --> 134 game.play_game()
#
# <ipython-input-4-498414cfe11d> in play_game(self)
#     111             self.p1.card = self.deck.draw()
#     112             self.p2.card = self.deck.draw()
# --> 113             self.print.card(self.p1, self.p2)
#     114             if self.p1.card > self.p2.card:
#     115                 self.p1.wins += 1
#
# AttributeError: 'Game' object has no attribute 'print'

# %%
from random import shuffle


class Card:
    suits = ["spades", "hearts", "diamonds", "clubs"]

    values = [None, None,"2", "3", "4", "5", "6", "7", "8", "9", "10",
              "Jack", "Queen", "King", "Ace"]

    def __init__(self, v, s):
        """suit + value are ints"""
        self.value = v
        self.suit = s

    def __lt__(self, c2):
        if self.value < c2.value:
            return True
        if self.value == c2.value:
#            if self.suit < c2.suit:
#                return True
#            else:
#                return False
            return self.suit < c2.suit
        return False

    def __gt__(self, c2):
        if self.value > c2.value:
            return True
        if self.value == c2.value:
#            if self.suit > c2.suit:
#                return True
#            else:
#                return False
            return self.suit > c2.suit
        return False

    def __repr__(self):
        v = self.values[self.value] +\
            " of " + \
            self.suits[self.suit]
        return v


class Deck:
    def __init__(self):
        self.cards = []
        for i in range(2, 15):
            for j in range(4):
                self.cards\
                    .append(Card(i,
                                 j))
        shuffle(self.cards)

#    def rm_card(self):
    def draw(self):
        if len(self.cards) == 0:
            return
        return self.cards.pop()

class Player:
    def __init__(self, name):
        self.wins = 0
        self.card = None
        self.name = name


class Game:
    def __init__(self):
        name1 = input("p1 name ")
        name2 = input("p2 name ")
        self.deck = Deck()
        self.p1 = Player(name1)
        self.p2 = Player(name2)

#    def wins(self, winner):
#        w = "{} wins this round"
#        w = w.format(winner)
#        print(w)

    def print_winner(self, winner):
        w = "{} wins this round"
        print(w.format(winner.name))

#    def draw(self, p1n, p1c, p2n, p2c):
#        d = "{} drew {} {} drew {}"
#        d = d.format(p1n, p1c, p2n, p2c)
#        print(d)

    def print_draw(self, p1,p2):
        d = "{} drew {} {} drew {}"
        print(d.format(p1.name, p1.card, p2.name, p2.card, ))

    def play_game(self):
        cards = self.deck.cards
        print("beginning War!")
        while len(cards) >= 2:
            m = "q to quit. Any " + \
                "key to play:"
            response = input(m)
            if response == 'q':
                break

#            p1c = self.deck.rm_card()
#            p2c = self.deck.rm_card()
#            p1n = self.p1.name
#            p2n = self.p2.name
#            self.draw(p1n, p1c, p2n, p2c)
#            if p1c > p2c:
#                self.p1.wins += 1
#                self.wins(self.p1.name)
#            else:
#                self.p2.wins += 1
#                self.wins(self.p2.name)

            self.p1.card = self.deck.draw()
            self.p2.card = self.deck.draw()
            self.print_draw(self.p1, self.p2)
            if self.p1.card > self.p2.card:
                self.p1.wins += 1
                self.print_winner(self.p1)
            else:
                self.p2.wins += 1
                self.print_winner(self.p2)

        win = self.winner(self.p1,
                         self.p2)
        print("War is over.{} wins"
              .format(win))

    def winner(self, p1, p2):
        if p1.wins > p2.wins:
            return p1.name
        if p1.wins < p2.wins:
            return p2.name
        return "It was a tie!"

game = Game()
game.play_game()
# Out:
# p1 name 1
# p2 name 1
# beginning War!
# q to quit. Any key to play:1
# 1 drew 2 of clubs 1 drew 9 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of spades 1 drew Ace of hearts
# 1 wins this round
# q to quit. Any key to play:
# 1 drew 10 of diamonds 1 drew 3 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 6 of diamonds 1 drew 8 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 10 of spades 1 drew King of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 6 of spades 1 drew King of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Queen of clubs 1 drew 6 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 2 of hearts 1 drew 2 of diamonds
# 1 wins this round
# q to quit. Any key to play:11
# 1 drew 4 of spades 1 drew Jack of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of hearts 1 drew 9 of hearts
# 1 wins this round
# q to quit. Any key to play:11
# 1 drew Jack of clubs 1 drew Ace of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of diamonds 1 drew Queen of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of diamonds 1 drew Queen of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of hearts 1 drew 6 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 7 of diamonds 1 drew Ace of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Ace of spades 1 drew 4 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 3 of clubs 1 drew 7 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 5 of clubs 1 drew 10 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 2 of spades 1 drew 8 of spades
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 7 of spades 1 drew 10 of clubs
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew Jack of spades 1 drew 5 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of diamonds 1 drew 4 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew King of spades 1 drew 7 of hearts
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 9 of clubs 1 drew Queen of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 4 of clubs 1 drew 9 of diamonds
# 1 wins this round
# q to quit. Any key to play:1
# 1 drew 8 of clubs 1 drew 5 of diamonds
# 1 wins this round
# War is over.1 wins
