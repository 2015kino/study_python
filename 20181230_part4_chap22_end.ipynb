# %%
for i in range(1, 101):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
def ss(number_list, n):
    found = False
    for i in number_list:
        if i == n:
            found = True
            break
        return found

numbers = range(0, 100)
s1 = ss(numbers, 2)
print(s1)
s2 = ss(numbers, 202)
print(s2)
# Out:
# False
# False

# %%
def ss(number_list, n):
    found = False
    for i in number_list:
        if i == n:
            found = True
            break
        return found

numbers = range(0, 100)
s1 = ss(numbers, 1)
print(s1)
s2 = ss(numbers, 202)
print(s2)
# Out:
# False
# False

# %%
def ss(number_list, n):
    found = False
    for i in number_list:
        if i == n:
            found = True
            break
        return found

numbers = range(0, 100)
s1 = ss(numbers, 2)
print(s1)
s2 = ss(numbers, 202)
print(s2)
# Out:
# False
# False

# %%
def ss(number_list, n):
    found = False
    for i in number_list:
        if i == n:
            found = True
            break
    return found

numbers = range(0, 100)
s1 = ss(numbers, 2)
print(s1)
s2 = ss(numbers, 202)
print(s2)
# Out:
# True
# False

# %%
def ss(number_list, n):
    found = False
    for i in number_list:
        if i == n:
            found = True
            break
    return found

numbers = range(0, 100)
s1 = ss(numbers, 2)
print(s1)
s2 = ss(numbers, 202)
print(s2)
# Out:
# True
# False

# %%
#False,Falseの返答になったのはfor文とreturnの位置の違い。

def palindrome(word):
    wrod = word.lower()
    return word(::-1) == word

print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
#   File "<ipython-input-7-c595a211495a>", line 5
#     return word(::-1) == word
#                 ^
# SyntaxError: invalid syntax

# %%
def palindrome(word):
    wrod = word.lower()
    return word[::-1] == word

print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# False

# %%
def is_palindrome(word):
    word = word.lower()
    return word[::-1] == word


print(is_palindrome("Mother"))
print(is_palindrome("Mom"))
# Out:
# False
# True

# %%
def palindrome(word):
    word = word.lower()
    return word[::-1] == word


print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# True

# %%
def palindrome(word):
    wrod = word.lower()
    return word[::-1] == word

print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# False

# %%
def palindrome(word):
    wrod = word.lower()
    return word[::-1] == word


print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# False

# %%
def palindrome(word):
    wrod = word.lower()
    return word[::-1] == word


print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# False

# %%
def palindrome(word):
    word = word.lower()
    return word[::-1] == word


print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# True

# %%
def palindrome(word):
    word = word.lower()
    return word[::-1] == word

print(palindrome("Mother"))
print(palindrome("Mom"))
# Out:
# False
# True

# %%
def anagram(w1,w2):
    w1 = w1.lower()
    w2 = w2.lower()
    return sorted(w1) == sorted(w2)

print(anagram("iceman","cinema"))
print(anagram("leaf","tree"))
# Out:
# True
# False

# %%
from collections import defaultdict

def count_characters(string):
    count_dict = defaultdict(int)
    for c in string:
        count_dict[c] += 1

    print(count_dict)

count_characters("Dynasty")
# Out:
# defaultdict(<class 'int'>, {'D': 1, 'y': 2, 'n': 1, 'a': 1, 's': 1, 't': 1})

# %%
from collections import Counter

def count_characters(string):
    count_dict = defaultdict(int)
    for c in string:
        count_dict[c] += 1

    print(Counter("Dynasty"))

# %%
from collections import defaultdict

def count_characters(string):
    count_dict = defaultdict(int)
    for c in string:
        count_dict[c] += 1

    print(count_dict)

count_characters("Dynasty")
# Out:
# defaultdict(<class 'int'>, {'D': 1, 'y': 2, 'n': 1, 'a': 1, 's': 1, 't': 1})

# %%
from collections import Counter
print(Counter("Dynasty"))
# Out:
# Counter({'y': 2, 'D': 1, 'n': 1, 'a': 1, 's': 1, 't': 1})

# %%
def bottles_of_beer(bob)
    """Prints Bottle of Beer on the  Wall lyrics.
    
    :param bob: Must be a positive integer.
    """
    if bob < 1:
        print("""No more bottles of beer on the wall.
              No more bottles of beer.""")
        return

    tmp = bob
    bob -= 1
    print("""()bottles of beer on the wall.
          () bottles of beer.
          Take one down, pass it around,
          () bottles of beer on the wall.
          """.format(tmp, tmp, bob))
    bottles_of_beer(bob)

bottles_of_beer(99)
# Out:
#   File "<ipython-input-21-d73b6503ea26>", line 1
#     def bottles_of_beer(bob)
#                             ^
# SyntaxError: invalid syntax

# %%
def bottles_of_beer(bob):
    """Prints Bottle of Beer on the  Wall lyrics.
    
    :param bob: Must be a positive integer.
    """
    if bob < 1:
        print("""No more bottles of beer on the wall.
              No more bottles of beer.""")
        return

    tmp = bob
    bob -= 1
    print("""()bottles of beer on the wall.
          () bottles of beer.
          Take one down, pass it around,
          () bottles of beer on the wall.
          """.format(tmp, tmp, bob))
    bottles_of_beer(bob)

bottles_of_beer(99)
# Out:
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
#           Take one down, pass it around,
#           () bottles of beer on the wall.
#
# ()bottles of beer on the wall.
#           () bottles of beer.
# ...

# %%
if bob < 1:
    print("""No more bottles of beer on the wall,
          No more bottles of beer.""")
    return
# Out:
#   File "<ipython-input-23-c3bc066d65f8>", line 4
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
bottles_of_beer(bob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9e65e77df732> in <module>()
# ----> 1 bottles_of_beer(bob)
#
# NameError: name 'bob' is not defined

# %%
#アルゴリズム：問題を解決するための一連の手順。
#探索アルゴリズム：データ構造の中から欲しいデータを探す処理（例えばリストから）。
#線形探索：シンプルな探索アルゴリズムで、データ構造の中なの要素を1つ１つ確認して探しているものを見つける手法。
#回文：初めから読んでも終わりから読んでも、同じになる文字列。
#アナグラム：単語の文字を並べ替えて別の単語を作る事。
#再帰：大きな問題を小さな問題に分割して解決する分割倒置法で使われる手法。小さな問題は比較的楽に解決できるだろう、
#という点に注目している。
#反復法：反復アルゴリズム。関数からその関数自信を呼び出すことで手順を繰り返し、問題を解決する。
#再帰終了条件：関数自身の呼び出しを終了する条件。

# Algorithm: a series of steps to solve the problem.
# Search Algorithm: Processing to find the data you want from the data structure (eg from the list).
# Linear search: A simple search algorithm that finds what you are looking for 
#by checking each element in the data structure one by one.
# Palindrome: A character string that will be the same whether you read from the beginning or read from the end.
#Anagram: rearrange the letters of a word and make another word.
# Recursion: a method used in the split-over method to break up large problems into small problems and solve them.
#We are paying attention to the fact that small problems can be solved relatively easily.
#Iterative: iterative algorithm. Repeat the procedure by calling the function confidence from the function,
#and solve the problem.
# Recursion termination condition: a condition to terminate the call of the function itself.
